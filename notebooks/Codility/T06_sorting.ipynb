# %% [markdown]
# # 4. Counting Elements
#
# ### Short Description

# %% [markdown]
# ### Task Description
#
# ----- Long Description

# %%
### code goes here  ###

# %%
### testing goes here

# %%
### score and review goes here
